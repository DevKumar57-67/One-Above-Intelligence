# %% [markdown]
# <a href="https://www.kaggle.com/code/devilbornfire/kaggle-mastery?scriptVersionId=352667015" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# *0.1 — UNDERSTANDING KAGGLE:*

# %% [markdown]
# *Kaggle is essentially an ecosystem with several interconnected components:*

# %%
'''                  KAGGLE
                       │
       ┌───────────────┼────────────────┐
       ▼               ▼                ▼
   DATASETS       COMPETITIONS       NOTEBOOKS
       │               │                │
       │               │                │
       └───────────────┼────────────────┘
                       ▼
                  COMMUNITY
                       │
          ┌────────────┼────────────┐
          ▼            ▼            ▼
       DISCUSSIONS    MODELS      COURSES

'''
# Out:
# '                  KAGGLE\n                       │\n       ┌───────────────┼────────────────┐\n       ▼               ▼                ▼\n   DATASETS       COMPETITIONS       NOTEBOOKS\n       │               │                │\n       │               │                │\n       └───────────────┼────────────────┘\n                       ▼\n                  COMMUNITY\n                       │\n          ┌────────────┼────────────┐\n          ▼            ▼            ▼\n       DISCUSSIONS    MODELS      COURSES\n\n'

# %% [markdown]
# *1️⃣ DATASETS:
#
# Datasets are our raw material.*

# %%
'''
Dataset
   ↓
Load
   ↓
Explore
   ↓
Clean
   ↓
Transform
   ↓
Train model
   ↓
Evaluate

'''

'''
Later we'll work with datasets involving:

Finance
Healthcare
NLP
Computer vision
Cybersecurity
Scientific computing
LLMs

'''
# Out:
# "\nLater we'll work with datasets involving:\n\nFinance\nHealthcare\nNLP\nComputer vision\nCybersecurity\nScientific computing\nLLMs\n\n"

# %% [markdown]
# *2️⃣ NOTEBOOKS:
#
# This is going to be the heart of One Above Research.
#
# A Kaggle notebook lets us combine:*

# %%
'''
Markdown
+
Python
+
Visualizations
+
Experiments
+
Results

'''
# Out:
# '\nMarkdown\n+\nPython\n+\nVisualizations\n+\nExperiments\n+\nResults\n\n'

# %%
# Code 
'''
import pandas as pd
data = pd.read_csv("source of the dataset")
df.head()

'''
# Out:
# '\nimport pandas as pd\ndata = pd.read_csv("source of the dataset")\ndf.head()\n\n'

# %% [markdown]
# *3️⃣ COMPETITIONS:
#
# Competitions will eventually become our training ground.
#
# A competition usually gives us:*

# %%
'''
Training data
       ↓
       ?
       ↓
Build model
       ↓
Generate predictions
       ↓
Submit
       ↓
Leaderboard

'''
# Out:
# '\nTraining data\n       ↓\n       ?\n       ↓\nBuild model\n       ↓\nGenerate predictions\n       ↓\nSubmit\n       ↓\nLeaderboard\n\n'

# %% [markdown]
# * FOR BEGINNERS:*

# %%
'''

EDA
↓
Baseline
↓
Simple model
↓
Submission

'''
# Out:
# '\n\nEDA\n↓\nBaseline\n↓\nSimple model\n↓\nSubmission\n\n'

# %% [markdown]
# *FOR INTERMEDIATES:*

# %%
'''
EDA
↓
Feature Engineering
↓
Cross Validation
↓
Hyperparameter Optimization
↓
Ensemble

'''
# Out:
# '\nEDA\n↓\nFeature Engineering\n↓\nCross Validation\n↓\nHyperparameter Optimization\n↓\nEnsemble\n\n'

# %% [markdown]
# *FOR ADVANCED:*

# %%
'''
Research
↓
Novel features
↓
Custom models
↓
Ensembling
↓
Experimentation

'''
# Out:
# '\nResearch\n↓\nNovel features\n↓\nCustom models\n↓\nEnsembling\n↓\nExperimentation\n\n'

# %% [markdown]
# *4️⃣ KAGGLE COMMUNITY:
#
# We'll use:
#
# Discussions
# Other people's notebooks
# Public datasets
# Models
# Research papers
# Competition solutions
#
# But there's an important rule for One Above Research:
#
# Don't blindly copy a high-scoring notebook.
#
# INSTEAD
# *

# %%
'''
Find solution
      ↓
Understand it
      ↓
Reproduce it
      ↓
Modify it
      ↓
Experiment
      ↓
Understand WHY


'''

#That's how we'll turn Kaggle into an actual learning platform.
# Out:
# '\nFind solution\n      ↓\nUnderstand it\n      ↓\nReproduce it\n      ↓\nModify it\n      ↓\nExperiment\n      ↓\nUnderstand WHY\n\n\n'

# %% [markdown]
# *# One Above Research
#
# ## Phase 0 — Kaggle AI Environment
#
# This notebook marks the beginning of my AI research journey.
#
# The goal of One Above Research is to progressively explore:
#
# - Machine Learning
# - Deep Learning
# - NLP
# - Computer Vision
# - Transformers
# - Generative AI
# - LLMs
# - Fine-tuning
# - Embeddings
# - Vector Databases
# - RAG
# - AI Agents
# - Multimodal AI
# - MLOps
# - AI Research
#
# Kaggle will be used as the experimental laboratory for this journey.
#
# ---
#
# ### Current Phase
#
# Phase 0 — Kaggle + AI Environment
#
# ### Status
#
# 🚀 Started*

# %% [markdown]
# *FIRST AI ENVIRONMENT TEST:*

# %%
#importing libraries
import sys
import numpy as np
import pandas as pd
import matplotlib 
import sklearn



print("Python:", sys.version)
print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Matplotlib:", matplotlib.__version__)
print("Scikit-learn:", sklearn.__version__)
# Out:
# Python: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# NumPy: 2.0.2
# Pandas: 2.3.3
# Matplotlib: 3.10.0
# Scikit-learn: 1.6.1

# %%
#checking the hardware
import torch

print("PyTorch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# PyTorch: 2.10.0+cpu
# CUDA available: False

# %%
'''
🧠 One Above Research Rule #1

From this point onward, every serious notebook should answer five questions:

1. What are we trying to solve?
2. What data do we have?
3. What method are we using?
4. What did the experiment show?
5. What did we learn?

This will prevent the series from becoming:

"Here's some Python code. Run it."

Instead, we're building the habit of an AI researcher/engineer.

'''
# Out:
# '\n🧠 One Above Research Rule #1\n\nFrom this point onward, every serious notebook should answer five questions:\n\n1. What are we trying to solve?\n2. What data do we have?\n3. What method are we using?\n4. What did the experiment show?\n5. What did we learn?\n\nThis will prevent the series from becoming:\n\n"Here\'s some Python code. Run it."\n\nInstead, we\'re building the habit of an AI researcher/engineer.\n\n'

# %% [markdown]
# *0.2.1 — WHAT IS A KAGGLE NOTEBOOK?*

# %%
'''
Think of a Kaggle Notebook as:

Jupyter Notebook + Cloud Compute + Datasets + GPU + Kaggle ecosystem

A notebook contains two primary types of cells:

📝 Markdown:

Used for explanation:

# My Experiment

We are testing whether feature scaling improves Logistic Regression.

🐍 Code:

Used for execution:

x = 10
print(x)

'''
# Out:
# '\nThink of a Kaggle Notebook as:\n\nJupyter Notebook + Cloud Compute + Datasets + GPU + Kaggle ecosystem\n\nA notebook contains two primary types of cells:\n\n📝 Markdown:\n\nUsed for explanation:\n\n# My Experiment\n\nWe are testing whether feature scaling improves Logistic Regression.\n\n🐍 Code:\n\nUsed for execution:\n\nx = 10\nprint(x)\n\n'

# %% [markdown]
# *A GOOD KAGGLE NOTEBOOK ALTERNATES BETWEEN THEM*

# %%
'''

Markdown
   ↓
Code
   ↓
Result
   ↓
Markdown
   ↓
Code
   ↓
Result

'''
# Out:
# '\n\nMarkdown\n   ↓\nCode\n   ↓\nResult\n   ↓\nMarkdown\n   ↓\nCode\n   ↓\nResult\n\n'

# %% [markdown]
# *0.2.2 — THE ANATOMY OF A PROFESSIONAL NOTEEBOOK:
#
# Our notebooks will eventually follow this structure:*

# %%
'''

┌───────────────────────────────┐
│ 1. TITLE                      │
├───────────────────────────────┤
│ 2. OBJECTIVE                  │
├───────────────────────────────┤
│ 3. IMPORTS                    │
├───────────────────────────────┤
│ 4. CONFIGURATION              │
├───────────────────────────────┤
│ 5. DATA                       │
├───────────────────────────────┤
│ 6. EDA                        │
├───────────────────────────────┤
│ 7. PREPROCESSING              │
├───────────────────────────────┤
│ 8. MODEL                      │
├───────────────────────────────┤
│ 9. TRAINING                   │
├───────────────────────────────┤
│ 10. EVALUATION                │
├───────────────────────────────┤
│ 11. EXPERIMENTS               │
├───────────────────────────────┤
│ 12. RESULTS                   │
├───────────────────────────────┤
│ 13. CONCLUSION                │
└───────────────────────────────┘

'''

#We'll gradually make this structure more sophisticated.
# Out:
# '\n\n┌───────────────────────────────┐\n│ 1. TITLE                      │\n├───────────────────────────────┤\n│ 2. OBJECTIVE                  │\n├───────────────────────────────┤\n│ 3. IMPORTS                    │\n├───────────────────────────────┤\n│ 4. CONFIGURATION              │\n├───────────────────────────────┤\n│ 5. DATA                       │\n├───────────────────────────────┤\n│ 6. EDA                        │\n├───────────────────────────────┤\n│ 7. PREPROCESSING              │\n├───────────────────────────────┤\n│ 8. MODEL                      │\n├───────────────────────────────┤\n│ 9. TRAINING                   │\n├───────────────────────────────┤\n│ 10. EVALUATION                │\n├───────────────────────────────┤\n│ 11. EXPERIMENTS               │\n├───────────────────────────────┤\n│ 12. RESULTS                   │\n├───────────────────────────────┤\n│ 13. CONCLUSION                │\n└───────────────────────────────┘\n\n'

# %% [markdown]
# *0.2.3 — Kaggle Notebook Sessions:*

# %%
#When you run a Kaggle notebook, you're working inside a temporary computing environment.

'''
Your Computer
     │
     │ internet
     ▼
Kaggle Server
     │
     ├── CPU
     ├── RAM
     ├── GPU/TPU
     ├── Python
     └── Libraries
'''
# Out:
# '\nYour Computer\n     │\n     │ internet\n     ▼\nKaggle Server\n     │\n     ├── CPU\n     ├── RAM\n     ├── GPU/TPU\n     ├── Python\n     └── Libraries\n'

# %% [markdown]
# *THE KAGGLE DIRECTORY:*

# %%
import os

print(os.listdir("/kaggle"))
# Out:
# ['src', 'lib', 'input', 'huggingface', 'nbdev', 'working']

# %% [markdown]
# *INSTALLING LIBRARIES IN KAGGLE:*

# %%
'''
Sometimes Kaggle already contains the library we need.

For example:

import numpy

works immediately.

But sometimes we'll need another package.

Then we can use:

# !pip install package_name

For example:

# !pip install -q some_package

The ! means we're executing a shell command from the notebook.

You may also encounter:

# %pip install package_name

For our course, we'll prefer %pip when installing Python packages inside notebooks because it is clearer about using the notebook's Python environment.
'''
# Out:
# "\nSometimes Kaggle already contains the library we need.\n\nFor example:\n\nimport numpy\n\nworks immediately.\n\nBut sometimes we'll need another package.\n\nThen we can use:\n\n!pip install package_name\n\nFor example:\n\n!pip install -q some_package\n\nThe ! means we're executing a shell command from the notebook.\n\nYou may also encounter:\n\n%pip install package_name\n\nFor our course, we'll prefer %pip when installing Python packages inside notebooks because it is clearer about using the notebook's Python environment.\n"

# %% [markdown]
# *0.2.7 — CPU vs GPU
#
# This is something you'll need to understand before Deep Learning.*

# %%
'''
CPU

Designed for general-purpose sequential/parallel computation.

CPU
├── Core
├── Core
├── Core
└── Core

'''
# Out:
# '\nCPU\n\nDesigned for general-purpose sequential/parallel computation.\n\nCPU\n├── Core\n├── Core\n├── Core\n└── Core\n\n'

# %%
'''
GPU

Designed for massive parallel computation.

GPU
├── thousands of smaller processing units
├── massive parallelism
└── high-throughput matrix operations

'''
# Out:
# '\nGPU\n\nDesigned for massive parallel computation.\n\nGPU\n├── thousands of smaller processing units\n├── massive parallelism\n└── high-throughput matrix operations\n\n'

# %%
'''
And neural networks are heavily based on:

Matrix multiplication
+
Tensor operations
'''

'''
Therefore GPUs become extremely useful for:

Deep Learning
CNNs
Transformers
LLMs
Diffusion
Fine-tuning

We'll go deep into this later.
'''
# Out:
# "\nTherefore GPUs become extremely useful for:\n\nDeep Learning\nCNNs\nTransformers\nLLMs\nDiffusion\nFine-tuning\n\nWe'll go deep into this later.\n"

# %% [markdown]
# *OAR-002 — Kaggle Notebook Fundamentals:
#
# Put this at the beginning:*

# %%
'''
# One Above Research

## OAR-002 — Kaggle Notebook Fundamentals

### Objective

Learn how Kaggle notebooks work as an AI experimentation environment.

### Topics

- Notebook structure
- Kaggle filesystem
- Python environment
- Package management
- CPU/GPU
- Notebook state
- Reproducibility

### Experiments

1. Environment inspection
2. Kaggle filesystem inspection
3. GPU detection
4. Package verification
5. Notebook state experiment

'''
# Out:
# '\n# One Above Research\n\n## OAR-002 — Kaggle Notebook Fundamentals\n\n### Objective\n\nLearn how Kaggle notebooks work as an AI experimentation environment.\n\n### Topics\n\n- Notebook structure\n- Kaggle filesystem\n- Python environment\n- Package management\n- CPU/GPU\n- Notebook state\n- Reproducibility\n\n### Experiments\n\n1. Environment inspection\n2. Kaggle filesystem inspection\n3. GPU detection\n4. Package verification\n5. Notebook state experiment\n\n'

# %% [markdown]
# *Mini Challenge:
#
# Before we move to 0.3 — Kaggle Datasets, solve this yourself.
#
# Write Python code that prints:*

# %%
'''
Python version
NumPy version
Pandas version
Scikit-learn version
PyTorch version
CUDA available
GPU name (if available)
'''

print(sys.version)
print(np.__version__)
print(pd.__version__)
print(sklearn.__version__)
print(torch.__version__)
print(torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# 2.0.2
# 2.3.3
# 1.6.1
# 2.10.0+cpu
# False

# %% [markdown]
# *Kaggle Datasets: From Raw Data → AI-Ready Data:
#
# Now we're entering one of the most important parts of the entire series.
#
# Models are only as useful as the data and experimental process behind them.
#
# Before we train a single serious ML model, you need to become comfortable with finding, loading, inspecting, understanding, and managing datasets.*

# %% [markdown]
# *0.3.1 — What is a Dataset?
#
# At the simplest level:
#
# A dataset is a collection of observations represented as data.*

# %%
'''
Tabular
  ↓
Images
  ↓
Text
  ↓
Audio
  ↓
Video
  ↓
Multimodal

'''
# Out:
# '\nTabular\n  ↓\nImages\n  ↓\nText\n  ↓\nAudio\n  ↓\nVideo\n  ↓\nMultimodal\n\n'

# %% [markdown]
# *0.3.2 — Kaggle's Three Important Data Sources:
#
# You'll encounter three major categories.
#
# 1. Kaggle Datasets:
#
# Community/public datasets.*
#
# 2. Competition Data:
#
# Data provided specifically for a Kaggle competition.
#
# 3. Your Own Dataset:
#
# You can also upload your own dataset

# %% [markdown]
# *0.3.3 — Attaching a Dataset:
#
# Inside a Kaggle notebook, datasets are normally added through the Add Data functionality.*

# %% [markdown]
# *0.3.5 — Loading a CSV:
#
# The most common beginner dataset format is CSV.*

# %%
'''
import pandas as pd

df = pd.read_csv("/kaggle/input/my-dataset/train.csv")
df 


'''

#The pandas library is used to work with datasets
# Out:
# '\nimport pandas as pd\n\ndf = pd.read_csv("/kaggle/input/my-dataset/train.csv")\ndf \n\n\n'

# %% [markdown]
# *Important Concept: DataFrame:
#
# df is a Pandas DataFrame.*

# %%
'''
DataFrame
    ↓
Table
    ↓
Rows + Columns
'''
# Out:
# '\nDataFrame\n    ↓\nTable\n    ↓\nRows + Columns\n'

# %% [markdown]
# *1. 🤖 KAGGLE MODELS:
#
# Kaggle Models is where models can be published, discovered, and reused.*

# %%
'''
Dataset
   ↓
Training
   ↓
Model
   ↓
Publish
   ↓
Other people can use it

'''
# Out:
# '\nDataset\n   ↓\nTraining\n   ↓\nModel\n   ↓\nPublish\n   ↓\nOther people can use it\n\n'

# %% [markdown]
# *9. 🌐 Kaggle API:
# The Kaggle API lets us interact with Kaggle programmatically.
# *

# %%
'''
Browser
 ↓
Find dataset
 ↓
Download
 ↓
Move file

'''

'''
Python / Terminal
       ↓
Kaggle API
       ↓
Dataset
'''
# Out:
# '\nPython / Terminal\n       ↓\nKaggle API\n       ↓\nDataset\n'

# %% [markdown]
# *Our Complete Kaggle Workflow:*

# %%
'''

                  KAGGLE
                     │
        ┌────────────┼────────────┐
        ▼            ▼            ▼
     DATASETS     NOTEBOOKS     MODELS
        │            │            │
        │            ▼            │
        │        EXPERIMENTS      │
        │            │            │
        └────────────┼────────────┘
                     ▼
                VERSIONING
                     │
                     ▼
              REPRODUCIBILITY
                     │
                     ▼
                DISCUSSIONS
                     │
                     ▼
                IMPROVEMENT
                     │
                     ▼
                  SHARE
                     │
                     ▼
              COMMUNITY FEEDBACK


'''
# Out:
# '\n\n                  KAGGLE\n                     │\n        ┌────────────┼────────────┐\n        ▼            ▼            ▼\n     DATASETS     NOTEBOOKS     MODELS\n        │            │            │\n        │            ▼            │\n        │        EXPERIMENTS      │\n        │            │            │\n        └────────────┼────────────┘\n                     ▼\n                VERSIONING\n                     │\n                     ▼\n              REPRODUCIBILITY\n                     │\n                     ▼\n                DISCUSSIONS\n                     │\n                     ▼\n                IMPROVEMENT\n                     │\n                     ▼\n                  SHARE\n                     │\n                     ▼\n              COMMUNITY FEEDBACK\n\n\n'

# %% [markdown]
# *THIS IS THE END FOR THIS NOTEBOOK IN MY NEXT NOTEBOOK WE WILL BE TAKING OUR FIRST HANDS ON LAB ON A DATASET*
